# %% [markdown]
# # Social circles: Twitter

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import matplotlib.pyplot as plt
import networkx as nx

# %%
# 加载数据
data = pd.read_csv('twitter_combined.txt', header=None, delim_whitespace=True)

# 创建事务（每个事务是一个与用户连接的用户列表）
transactions = data.groupby(0)[1].apply(list).tolist()

# 对事务进行一次热编码
encoder = TransactionEncoder()
encoded_array = encoder.fit_transform(transactions)
df = pd.DataFrame(encoded_array, columns=encoder.columns_)
# Out:
# C:\Users\86173\AppData\Local\Temp\ipykernel_13352\2060050930.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv('twitter_combined.txt', header=None, delim_whitespace=True)

# %%
# 使用 apriori 算法生成频繁项集
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)

# 生成关联规则
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

# 分析结果
print(frequent_itemsets.head())
print(rules.head())
# Out:
#     support  itemsets
# 0  0.015978   (10350)
# 1  0.030429   (15913)
# 2  0.017561  (428333)
# 3  0.011855  (657863)
# 4  0.016648  (783214)
#   antecedents consequents  antecedent support  consequent support   support  \
# 0  (48485771)     (15913)            0.020001            0.030429  0.011227
# 1  (59804598)     (15913)            0.017133            0.030429  0.010172
# 2   (8088112)  (22462180)            0.010186            0.035251  0.010000
# 3   (8088112)  (40981798)            0.010186            0.045879  0.010000
# 4  (15853668)  (14654965)            0.019074            0.015265  0.010871
#
#    confidence       lift  leverage  conviction  zhangs_metric
# 0    0.561341  18.447406  0.010619    2.210306       0.965095
# 1    0.593672  19.509902  0.009650    2.386177       0.965283
# 2    0.981793  27.851365  0.009641   52.986975       0.974016
# 3    0.981793  21.399479  0.009533   52.403246       0.963080
# 4    0.569933  37.336983  0.010580    2.289724       0.992141

# %%
# 利用图形可视化结果
plt.rcParams['font.sans-serif']=['Microsoft YaHei']
fig, ax = plt.subplots(figsize=(10, 8))
GA = nx.from_pandas_edgelist(rules, source='antecedents', target='consequents')
nx.draw_networkx(GA, ax=ax, with_labels=False, node_size=50, node_color='lightblue')
plt.title('用户频繁连接网络图')
plt.show()

# %% [markdown]
# 我们使用的是 Twitter 用户的连接数据。具体来说，我们是在找出哪些用户经常一起出现在其他用户的关注列表中，这可以帮助我们识别社交圈子或者影响力群体。
#
# 预处理：
# 我们首先将数据读取为一个列表，其中每个元素是一个元组，表示一个用户关注另一个用户。
# 接着，我们将这些关注关系转换为事务数据。每个事务代表一个用户所关注的所有用户的集合。
# 独热编码：
# 为了使用 apriori 算法，我们需要将事务数据转换为独热编码格式。这意味着每个用户都被表示为一个列，如果在某个事务（即某个用户的关注列表）中出现了该用户，那么相应的列就为 True，否则为 False。
# 频繁项集生成：
# 使用 apriori 算法从独热编码的数据中找出频繁项集。频繁项集是指那些在数据集中频繁出现的用户集合，这些集合出现的频率高于我们设定的阈值（min_support）。
# 关联规则挖掘：
# 从频繁项集中生成关联规则。关联规则表示为“如果关注了用户A，那么也可能关注用户B”。我们使用置信度（confidence）来衡量规则的强度，它告诉我们在关注了规则左侧的用户的情况下，有多大比例的人也关注了规则右侧的用户。
# 可视化：
# 使用网络图来可视化这些关联规则，节点表示用户，边表示频繁的关联规则。这有助于我们直观地看到哪些用户间存在较强的连接关系。
#
# 分析应用：
# 社区发现：通过识别频繁共同出现的用户群，我们可以找到紧密相连的用户社区或群组。
# 影响力分析：确定哪些用户在网络中具有中心地位，可能影响其他用户。
# 推荐系统：在推荐关注用户时，可以利用发现的模式推荐那些经常一起被关注的用户。

# %% [markdown]
# ## 将该模式命名为关联用户模式

# %%
import os
import pyfpgrowth

# %%
# Step 1: Load all .edges files from the folder
folder_path = 'twitter子图'  # Update this to your folder path
all_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.edges')]
transactions = []

for file in all_files:
    df = pd.read_csv(file, delim_whitespace=True, header=None, names=['source', 'target'])
    for index, row in df.iterrows():
        transactions.append([str(row['source']), str(row['target'])])

# Step 2: Find frequent patterns
patterns = pyfpgrowth.find_frequent_patterns(transactions, 2)  # Adjust the support threshold as necessary

# Step 3: Visualize the graph (simplified for performance)
G = nx.DiGraph()
for edge in transactions:
    G.add_edge(edge[0], edge[1])
# Out:
# C:\Users\86173\AppData\Local\Temp\ipykernel_13352\521380614.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file, delim_whitespace=True, header=None, names=['source', 'target'])
# C:\Users\86173\AppData\Local\Temp\ipykernel_13352\521380614.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file, delim_whitespace=True, header=None, names=['source', 'target'])
# C:\Users\86173\AppData\Local\Temp\ipykernel_13352\521380614.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file, delim_whitespace=True, header=None, names=['source', 'target'])
# C:\Users\86173\AppData\Local\Temp\ipykernel_13352\521380614.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file, delim_whitespace=True, header=None, names=['source', 'target'])
# C:\Users\86173\AppData\Local\Temp\ipykernel_13352\521380614.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file, delim_whitespace=True, header=None, names=['source', 'target'])
# C:\Users\86173\AppData\Local\Temp\ipykernel_13352\521380614.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file, delim_whitespace=True, header=None, names=['source', 'target'])
# C:\Users\86173\AppData\Local\Temp\ipykernel_13352\521380614.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file, delim_whitespace=True, header=None, names=['source', 'target'])

# %%
# Print frequent patterns
print("Frequent patterns:")
for pattern, support in patterns.items():
    print(f"Pattern: {pattern}, Support: {support}")
# Out:
# Frequent patterns:
# Pattern: ('398874773',), Support: 2
# Pattern: ('15543818',), Support: 2
# Pattern: ('15543818', '19507576'), Support: 2
# Pattern: ('1656891',), Support: 2
# Pattern: ('1656891', '5994452'), Support: 2
# Pattern: ('5436752',), Support: 2
# Pattern: ('81962011',), Support: 2
# Pattern: ('10044992',), Support: 2
# Pattern: ('10044992', '15109716'), Support: 2
# Pattern: ('15725851',), Support: 2
# Pattern: ('7821492',), Support: 2
# Pattern: ('23771687',), Support: 2
# Pattern: ('23771687', '668423'), Support: 2
# Pattern: ('18729020',), Support: 2
# Pattern: ('15814666', '18729020'), Support: 2
# Pattern: ('76561747',), Support: 2
# Pattern: ('19323197',), Support: 2
# Pattern: ('32907513',), Support: 2
# Pattern: ('14538636',), Support: 2
# Pattern: ('15567998',), Support: 2
# Pattern: ('1899531',), Support: 2
# Pattern: ('14294508',), Support: 2
# Pattern: ('16953895',), Support: 2
# Pattern: ('109118877',), Support: 2
# Pattern: ('109118877', '83883736'), Support: 2
# Pattern: ('18660360',), Support: 2
# Pattern: ('18660360', '31352453'), Support: 2
# Pattern: ('29674222',), Support: 2
# Pattern: ('24807616',), Support: 2
# Pattern: ('525392721',), Support: 2
# Pattern: ('16131973',), Support: 2
# Pattern: ('22954987',), Support: 2
# Pattern: ('259471543',), Support: 2
# Pattern: ('259471543', '5496642'), Support: 2
# Pattern: ('25202284',), Support: 2
# Pattern: ('17193794',), Support: 2
# Pattern: ('15465147',), Support: 2
# Pattern: ('6704322',), Support: 2
# Pattern: ('48717817',), Support: 2
# Pattern: ('216622015',), Support: 2
# Pattern: ('191956971',), Support: 2
# Pattern: ('151466572',), Support: 2
# Pattern: ('18454912',), Support: 2
# Pattern: ('182013328',), Support: 2
# Pattern: ('61485111',), Support: 2
# Pattern: ('9528212',), Support: 2
# Pattern: ('806170', '9528212'), Support: 2
# Pattern: ('16751855',), Support: 2
# Pattern: ('65502805',), Support: 2
# Pattern: ('62083093',), Support: 2
# Pattern: ('14352556', '62083093'), Support: 2
# Pattern: ('20290970',), Support: 2
# Pattern: ('159323374',), Support: 2
# Pattern: ('14124059', '159323374'), Support: 2
# Pattern: ('360882965',), Support: 3
# Pattern: ('198410517',), Support: 3
# Pattern: ('198410517', '79033767'), Support: 2
# Pattern: ('98065221',), Support: 3
# Pattern: ('8132642', '98065221'), Support: 2
# Pattern: ('47015938',), Support: 3
# Pattern: ('6368672',), Support: 3
# Pattern: ('20221130',), Support: 3
# Pattern: ('12081222',), Support: 3
# Pattern: ('487072890',), Support: 3
# Pattern: ('13538092',), Support: 3
# Pattern: ('13538092', '16007011'), Support: 2
# Pattern: ('14202817',), Support: 3
# Pattern: ('14120215',), Support: 3
# Pattern: ('44655553',), Support: 3
# Pattern: ('10266802', '44655553'), Support: 2
# Pattern: ('51662201',), Support: 3
# Pattern: ('15527013', '51662201'), Support: 2
# Pattern: ('16657117',), Support: 3
# Pattern: ('16974245',), Support: 3
# Pattern: ('1501471', '16974245'), Support: 2
# Pattern: ('16871402',), Support: 3
# Pattern: ('15666545',), Support: 3
# Pattern: ('14538601',), Support: 3
# Pattern: ('31352453',), Support: 3
# Pattern: ('17964423',), Support: 3
# Pattern: ('17964423', '36182824'), Support: 2
# Pattern: ('15534579',), Support: 3
# Pattern: ('15214543',), Support: 3
# Pattern: ('15214543', '78231411'), Support: 2
# Pattern: ('47069130',), Support: 3
# Pattern: ('442782547',), Support: 3
# Pattern: ('171550741',), Support: 3
# Pattern: ('113434348', '171550741'), Support: 2
# Pattern: ('17260136',), Support: 3
# Pattern: ('54330691',), Support: 3
# Pattern: ('268907935',), Support: 3
# Pattern: ('291758611',), Support: 3
# Pattern: ('41255213',), Support: 3
# Pattern: ('198519537',), Support: 3
# Pattern: ('198519537', '4298461'), Support: 2
# Pattern: ('17021778',), Support: 3
# Pattern: ('17021778', '85923804'), Support: 2
# Pattern: ('179980928',), Support: 3
# Pattern: ('12101862', '179980928'), Support: 2
# Pattern: ('156001879',), Support: 3
# Pattern: ('156001879', '5676102'), Support: 2
# Pattern: ('663273',), Support: 3
# Pattern: ('105673792',), Support: 3
# Pattern: ('105673792', '7434252'), Support: 2
# Pattern: ('18041656',), Support: 3
# Pattern: ('165964253',), Support: 4
# Pattern: ('15236339',), Support: 4
# Pattern: ('606083',), Support: 4
# Pattern: ('18974638', '18976476'), Support: 2
# Pattern: ('18976476', '35357461'), Support: 2
# Pattern: ('130268655',), Support: 4
# Pattern: ('148943',), Support: 4
# Pattern: ('148943', '15911247'), Support: 2
# Pattern: ('5264791',), Support: 4
# Pattern: ('21196272',), Support: 4
# Pattern: ('21196272', '5827292'), Support: 2
# Pattern: ('19483147',), Support: 4
# Pattern: ('7461782',), Support: 4
# Pattern: ('15109716', '7461782'), Support: 2
# Pattern: ('12544312',), Support: 4
# Pattern: ('1859981',), Support: 4
# Pattern: ('14958507',), Support: 4
# Pattern: ('15028425',), Support: 4
# Pattern: ('15028425', '45919912'), Support: 2
# Pattern: ('15456622', '18103410'), Support: 2
# Pattern: ('15527013', '18103410'), Support: 2
# Pattern: ('17814635',), Support: 4
# Pattern: ('17814635', '818489'), Support: 2
# Pattern: ('14667274',), Support: 4
# Pattern: ('21212145',), Support: 4
# Pattern: ('22559840',), Support: 4
# Pattern: ('15527013', '22559840'), Support: 2
# Pattern: ('21931952',), Support: 4
# Pattern: ('15312009',), Support: 4
# Pattern: ('14179822',), Support: 4
# Pattern: ('678083',), Support: 4
# Pattern: ('45919912', '678083'), Support: 2
# Pattern: ('40654543',), Support: 4
# Pattern: ('40654543', '9245812'), Support: 2
# Pattern: ('82488357',), Support: 4
# Pattern: ('24852559',), Support: 4
# Pattern: ('22814809',), Support: 4
# Pattern: ('22814809', '34260638'), Support: 2
# Pattern: ('9445662',), Support: 4
# Pattern: ('5496642', '9445662'), Support: 2
# Pattern: ('14248648',), Support: 4
# Pattern: ('420537982',), Support: 4
# Pattern: ('19832728',), Support: 4
# Pattern: ('19832728', '246981903'), Support: 2
# Pattern: ('14551043',), Support: 4
# Pattern: ('16893966',), Support: 4
# Pattern: ('86985177',), Support: 4
# Pattern: ('80656590', '86985177'), Support: 2
# Pattern: ('10314702',), Support: 4
# Pattern: ('55932764',), Support: 4
# Pattern: ('41791341',), Support: 4
# Pattern: ('41047618', '41791341'), Support: 2
# Pattern: ('106646062',), Support: 4
# Pattern: ('7984262',), Support: 4
# Pattern: ('5496642', '7984262'), Support: 2
# Pattern: ('60146669',), Support: 4
# Pattern: ('14111698', '60146669'), Support: 2
# Pattern: ('22328084',), Support: 4
# Pattern: ('1950981',), Support: 4
# Pattern: ('138034438',), Support: 4
# Pattern: ('14940487',), Support: 4
# Pattern: ('198693040',), Support: 4
# Pattern: ('13434092', '198693040'), Support: 2
# Pattern: ('6244092',), Support: 4
# Pattern: ('1976611', '6244092'), Support: 2
# Pattern: ('551433993',), Support: 5
# Pattern: ('18974638',), Support: 5
# Pattern: ('18974638', '35357461'), Support: 2
# Pattern: ('8132642',), Support: 5
# Pattern: ('18248772',), Support: 5
# Pattern: ('12800212', '18248772'), Support: 2
# Pattern: ('460693601',), Support: 5
# Pattern: ('305888449',), Support: 5
# Pattern: ('16734561',), Support: 5
# Pattern: ('8940282',), Support: 5
# Pattern: ('62415556', '8940282'), Support: 2
# Pattern: ('109186893',), Support: 5
# Pattern: ('109186893', '155696919'), Support: 2
# Pattern: ('80273245',), Support: 5
# Pattern: ('17129546',), Support: 5
# Pattern: ('17129546', '90630206'), Support: 2
# Pattern: ('9453872',), Support: 5
# Pattern: ('10266802', '131884083'), Support: 2
# Pattern: ('131884083', '27242126'), Support: 2
# Pattern: ('14973377',), Support: 5
# Pattern: ('14973377', '15814666'), Support: 2
# Pattern: ('246915368',), Support: 5
# Pattern: ('128704224', '246915368'), Support: 2
# Pattern: ('24583',), Support: 5
# Pattern: ('24583', '7826472'), Support: 2
# Pattern: ('112296194',), Support: 5
# Pattern: ('112296194', '7826472'), Support: 2
# Pattern: ('168084831',), Support: 5
# Pattern: ('6216912',), Support: 5
# Pattern: ('14126972',), Support: 5
# Pattern: ('240941560', '3551781'), Support: 2
# Pattern: ('240941560', '80656590'), Support: 2
# Pattern: ('25056092',), Support: 5
# Pattern: ('25056092', '41047618'), Support: 2
# Pattern: ('16634301',), Support: 5
# Pattern: ('16634301', '690973'), Support: 2
# Pattern: ('240936932',), Support: 5
# Pattern: ('288019271',), Support: 5
# Pattern: ('6003302',), Support: 5
# Pattern: ('10461992',), Support: 5
# Pattern: ('11323282',), Support: 5
# Pattern: ('11323282', '9363302'), Support: 2
# Pattern: ('81231895', '821449'), Support: 2
# Pattern: ('14111698', '81231895'), Support: 2
# Pattern: ('17885184',), Support: 5
# Pattern: ('17885184', '643443'), Support: 2
# Pattern: ('55252378',), Support: 5
# Pattern: ('15335141',), Support: 5
# Pattern: ('14622630',), Support: 5
# Pattern: ('14622630', '30495974'), Support: 2
# Pattern: ('161739794',), Support: 5
# Pattern: ('23279911',), Support: 5
# Pattern: ('23279911', '5637652'), Support: 2
# Pattern: ('2419',), Support: 5
# Pattern: ('71062740',), Support: 5
# Pattern: ('223048206',), Support: 5
# Pattern: ('58166411',), Support: 6
# Pattern: ('25583917',), Support: 6
# Pattern: ('17729005', '25583917'), Support: 2
# Pattern: ('2372',), Support: 6
# Pattern: ('2372', '27985216'), Support: 2
# Pattern: ('19327052',), Support: 6
# Pattern: ('16317798', '19327052'), Support: 2
# Pattern: ('19507576',), Support: 6
# Pattern: ('14904282', '19507576'), Support: 2
# Pattern: ('13648692',), Support: 6
# Pattern: ('13648692', '16803822'), Support: 2
# Pattern: ('14313755',), Support: 6
# Pattern: ('136865608', '353101127'), Support: 2
# Pattern: ('155696919', '353101127'), Support: 2
# Pattern: ('10266802', '61819621'), Support: 2
# Pattern: ('27242126', '61819621'), Support: 2
# Pattern: ('32765534',), Support: 6
# Pattern: ('24008967', '32765534'), Support: 2
# Pattern: ('90630206',), Support: 6
# Pattern: ('15527013', '90630206'), Support: 2
# Pattern: ('4519121',), Support: 6
# Pattern: ('18344173',), Support: 6
# Pattern: ('18344173', '24008967'), Support: 2
# Pattern: ('17870415', '9663492'), Support: 2
# Pattern: ('17643774', '9663492'), Support: 2
# Pattern: ('13274152',), Support: 6
# Pattern: ('13274152', '15527013'), Support: 2
# Pattern: ('16901455',), Support: 6
# Pattern: ('15527013', '16901455'), Support: 2
# Pattern: ('126881128',), Support: 6
# Pattern: ('17293897',), Support: 6
# Pattern: ('17293897', '24608680'), Support: 2
# Pattern: ('16457564',), Support: 6
# Pattern: ('15527013', '16457564'), Support: 2
# Pattern: ('31986700', '618593'), Support: 2
# Pattern: ('17870501', '31986700'), Support: 2
# Pattern: ('115430599',), Support: 6
# Pattern: ('17577445', '23110087'), Support: 2
# Pattern: ('17872874', '23110087'), Support: 2
# Pattern: ('16905553', '23110087'), Support: 2
# Pattern: ('7826472',), Support: 6
# Pattern: ('53459595',), Support: 6
# Pattern: ('690973', '755068'), Support: 2
# Pattern: ('5496642', '690973'), Support: 2
# Pattern: ('14922225',), Support: 6
# Pattern: ('31572616',), Support: 6
# Pattern: ('28234516',), Support: 6
# Pattern: ('41047618',), Support: 6
# Pattern: ('4298461',), Support: 6
# Pattern: ('9486332',), Support: 6
# Pattern: ('37444945',), Support: 6
# Pattern: ('177366676',), Support: 6
# Pattern: ('114284224',), Support: 6
# Pattern: ('121887978',), Support: 6
# Pattern: ('121887978', '586'), Support: 2
# Pattern: ('3388481',), Support: 6
# Pattern: ('13837292', '3388481'), Support: 2
# Pattern: ('20496869',), Support: 7
# Pattern: ('20496869', '22253'), Support: 2
# Pattern: ('15639334',), Support: 7
# Pattern: ('15639334', '652193'), Support: 2
# Pattern: ('155696919',), Support: 7
# Pattern: ('136865608', '155696919'), Support: 2
# Pattern: ('17798441', '18414485'), Support: 2
# Pattern: ('17798441', '5994452'), Support: 2
# Pattern: ('1678471', '17798441'), Support: 2
# Pattern: ('1765921', '757502'), Support: 2
# Pattern: ('2727051', '757502'), Support: 2
# Pattern: ('248049056',), Support: 7
# Pattern: ('1471021',), Support: 7
# Pattern: ('11340982', '1471021'), Support: 2
# Pattern: ('36182824',), Support: 7
# Pattern: ('136055942',), Support: 7
# Pattern: ('41577194', '41602160'), Support: 2
# Pattern: ('41577194', '759251'), Support: 2
# Pattern: ('145171509', '389380307'), Support: 2
# Pattern: ('389380307', '6066602'), Support: 2
# Pattern: ('57510717',), Support: 7
# Pattern: ('286375309',), Support: 7
# Pattern: ('246981903',), Support: 7
# Pattern: ('46842641',), Support: 7
# Pattern: ('46842641', '712783'), Support: 2
# Pattern: ('16203661',), Support: 7
# Pattern: ('2064501',), Support: 7
# Pattern: ('77007853',), Support: 7
# Pattern: ('22841103', '77007853'), Support: 2
# Pattern: ('239760107',), Support: 7
# Pattern: ('10228272', '239760107'), Support: 2
# Pattern: ('145329562',), Support: 7
# Pattern: ('15578992',), Support: 7
# Pattern: ('15578992', '22841103'), Support: 2
# Pattern: ('15294787', '813491'), Support: 2
# Pattern: ('14058661', '15294787'), Support: 2
# Pattern: ('11362622', '6813682'), Support: 2
# Pattern: ('11362622', '12199652'), Support: 2
# Pattern: ('361943754',), Support: 7
# Pattern: ('211089576',), Support: 7
# Pattern: ('211089576', '621713'), Support: 2
# Pattern: ('9462782',), Support: 7
# Pattern: ('1594501',), Support: 7
# Pattern: ('14297283', '1594501'), Support: 2
# Pattern: ('16211399',), Support: 7
# Pattern: ('18432997', '8168192'), Support: 2
# Pattern: ('16959786', '18432997'), Support: 2
# Pattern: ('15438005', '18432997'), Support: 2
# Pattern: ('57739496',), Support: 8
# Pattern: ('57739496', '9943672'), Support: 2
# Pattern: ('136865608',), Support: 8
# Pattern: ('17561826', '6331462'), Support: 2
# Pattern: ('17561826', '47'), Support: 2
# Pattern: ('15384741', '9611352'), Support: 2
# Pattern: ('15801446', '9611352'), Support: 2
# Pattern: ('17729005', '9611352'), Support: 2
# Pattern: ('163449492',), Support: 8
# Pattern: ('15304923',), Support: 8
# Pattern: ('83971810',), Support: 8
# Pattern: ('14087951', '21145764'), Support: 2
# Pattern: ('14809096', '21145764'), Support: 2
# Pattern: ('14904282',), Support: 8
# Pattern: ('17853760', '641433'), Support: 2
# Pattern: ('641433', '809760'), Support: 2
# Pattern: ('24608680',), Support: 8
# Pattern: ('24608680', '809760'), Support: 2
# Pattern: ('38272894',), Support: 8
# Pattern: ('259110723',), Support: 8
# Pattern: ('27885519',), Support: 8
# Pattern: ('16724361', '27885519'), Support: 2
# Pattern: ('127790650',), Support: 8
# Pattern: ('127790650', '135162675'), Support: 2
# Pattern: ('33540121',), Support: 8
# Pattern: ('33540121', '9844372'), Support: 2
# Pattern: ('15862848', '164246722'), Support: 2
# Pattern: ('145171509', '164246722'), Support: 2
# Pattern: ('164246722', '235117387'), Support: 2
# Pattern: ('164246722', '6066602'), Support: 2
# Pattern: ('75283712',), Support: 8
# Pattern: ('176507184',), Support: 8
# Pattern: ('3551781',), Support: 8
# Pattern: ('3551781', '80656590'), Support: 2
# Pattern: ('85923804',), Support: 8
# Pattern: ('53825477',), Support: 8
# Pattern: ('223483131',), Support: 8
# Pattern: ('15437804', '806170'), Support: 2
# Pattern: ('11628', '15437804'), Support: 2
# Pattern: ('14124059', '18208247'), Support: 2
# Pattern: ('14405111', '18208247'), Support: 2
# Pattern: ('18296076',), Support: 8
# Pattern: ('17449991', '18296076'), Support: 2
# Pattern: ('789314',), Support: 8
# Pattern: ('229523', '789314'), Support: 2
# Pattern: ('1186', '14'), Support: 2
# Pattern: ('14', '380'), Support: 2
# Pattern: ('104937383',), Support: 9
# Pattern: ('17938005', '9283582'), Support: 2
# Pattern: ('17938005', '9767472'), Support: 2
# Pattern: ('14819149', '17938005'), Support: 2
# Pattern: ('17938005', '8708232'), Support: 2
# Pattern: ('10587552', '15166546'), Support: 2
# Pattern: ('15166546', '8630302'), Support: 2
# Pattern: ('818489',), Support: 9
# Pattern: ('15456622', '95822575'), Support: 2
# Pattern: ('15527013', '95822575'), Support: 2
# Pattern: ('17643774', '95822575'), Support: 2
# Pattern: ('16129920',), Support: 9
# Pattern: ('27242126',), Support: 9
# Pattern: ('10266802', '27242126'), Support: 2
# Pattern: ('16530279',), Support: 9
# Pattern: ('15527013', '16530279'), Support: 2
# Pattern: ('107412282',), Support: 9
# Pattern: ('107412282', '15862848'), Support: 2
# Pattern: ('235117387', '26641462'), Support: 2
# Pattern: ('26641462', '6066602'), Support: 2
# Pattern: ('233614469',), Support: 9
# Pattern: ('18731347', '233614469'), Support: 2
# Pattern: ('14181876',), Support: 9
# Pattern: ('22841103',), Support: 9
# Pattern: ('47787563',), Support: 9
# Pattern: ('17346342', '309366491'), Support: 2
# Pattern: ('17346342', '275353050'), Support: 2
# Pattern: ('14058661', '263553997'), Support: 2
# Pattern: ('11336782', '263553997'), Support: 2
# Pattern: ('2038', '949161'), Support: 2
# Pattern: ('627363', '949161'), Support: 2
# Pattern: ('10359172',), Support: 9
# Pattern: ('10359172', '18139167'), Support: 2
# Pattern: ('656933', '9363302'), Support: 2
# Pattern: ('13405', '656933'), Support: 2
# Pattern: ('1375251', '14976534'), Support: 2
# Pattern: ('14976534', '16993577'), Support: 2
# Pattern: ('1976611', '627363'), Support: 2
# Pattern: ('1976611', '7434252'), Support: 2
# Pattern: ('1976611', '655613'), Support: 2
# Pattern: ('12307282', '17841702'), Support: 2
# Pattern: ('17841702', '297174372'), Support: 2
# Pattern: ('14616067', '17841702'), Support: 2
# Pattern: ('11375732', '40341246'), Support: 2
# Pattern: ('12199652', '40341246'), Support: 2
# Pattern: ('13839772', '17129553'), Support: 2
# Pattern: ('13839772', '3191321'), Support: 2
# Pattern: ('10587552', '24340234'), Support: 2
# Pattern: ('15384741', '24340234'), Support: 2
# Pattern: ('17729005', '24340234'), Support: 2
# Pattern: ('21965123', '24340234'), Support: 2
# Pattern: ('271605782', '9411772'), Support: 2
# Pattern: ('14142965', '271605782'), Support: 2
# Pattern: ('14086492', '271605782'), Support: 2
# Pattern: ('16215038', '16803822'), Support: 2
# Pattern: ('14086492', '16215038'), Support: 2
# Pattern: ('16215038', '9411772'), Support: 2
# Pattern: ('16215038', '18317233'), Support: 2
# Pattern: ('15162141', '22253'), Support: 2
# Pattern: ('15162141', '57378470'), Support: 2
# Pattern: ('15162141', '1678471'), Support: 2
# Pattern: ('15162141', '16912257'), Support: 2
# Pattern: ('14367669', '15162141'), Support: 2
# Pattern: ('1057431', '17870501'), Support: 2
# Pattern: ('1057431', '17870415'), Support: 2
# Pattern: ('19996594', '21523946'), Support: 2
# Pattern: ('21523946', '755603'), Support: 2
# Pattern: ('15527013', '21523946'), Support: 2
# Pattern: ('21523946', '9870342'), Support: 2
# Pattern: ('2029971', '91718540'), Support: 2
# Pattern: ('2029971', '50888802'), Support: 2
# Pattern: ('2029971', '57186667'), Support: 2
# Pattern: ('15527013', '2029971'), Support: 2
# Pattern: ('16167236',), Support: 10
# Pattern: ('110458336', '16167236'), Support: 2
# Pattern: ('19294743',), Support: 10
# Pattern: ('198494684', '329600057'), Support: 2
# Pattern: ('198494684', '95428712'), Support: 2
# Pattern: ('104585489', '198494684'), Support: 2
# Pattern: ('265902729', '7589572'), Support: 2
# Pattern: ('21642976', '265902729'), Support: 2
# Pattern: ('26514893', '265902729'), Support: 2
# Pattern: ('146513211', '19874960'), Support: 2
# Pattern: ('146513211', '8170292'), Support: 2
# Pattern: ('46346835',), Support: 10
# Pattern: ('18840531', '46346835'), Support: 2
# Pattern: ('61147653',), Support: 10
# Pattern: ('14248719', '525268196'), Support: 2
# Pattern: ('15387870', '525268196'), Support: 2
# Pattern: ('30957246', '525268196'), Support: 2
# Pattern: ('16792453', '525268196'), Support: 2
# Pattern: ('14154082', '27478849'), Support: 2
# Pattern: ('14154082', '6339822'), Support: 2
# Pattern: ('19459100',), Support: 10
# Pattern: ('19459100', '627363'), Support: 2
# Pattern: ('36412963',), Support: 10
# Pattern: ('36412963', '50393960'), Support: 2
# Pattern: ('2038', '9235972'), Support: 2
# Pattern: ('6339822', '9235972'), Support: 2
# Pattern: ('14290339', '627363'), Support: 2
# Pattern: ('1375251', '14290339'), Support: 2
# Pattern: ('14290339', '3594701'), Support: 2
# Pattern: ('14290339', '655613'), Support: 2
# Pattern: ('14290339', '758185'), Support: 2
# Pattern: ('14086492', '15911247'), Support: 2
# Pattern: ('15911247', '9411772'), Support: 2
# Pattern: ('15911247', '20554406'), Support: 2
# Pattern: ('15911247', '18317233'), Support: 2
# Pattern: ('14838800',), Support: 11
# Pattern: ('16934483', '35357461'), Support: 2
# Pattern: ('16934483', '183836186'), Support: 2
# Pattern: ('15583257', '16934483'), Support: 2
# Pattern: ('15187243', '5634142'), Support: 2
# Pattern: ('15187243', '19208772'), Support: 2
# Pattern: ('15187243', '15583257'), Support: 2
# Pattern: ('15187243', '18414485'), Support: 2
# Pattern: ('15187243', '1678471'), Support: 2
# Pattern: ('5827292',), Support: 11
# Pattern: ('16461070', '287713'), Support: 2
# Pattern: ('16461070', '652193'), Support: 2
# Pattern: ('16461070', '9863222'), Support: 2
# Pattern: ('16461070', '586'), Support: 2
# Pattern: ('487851005', '6088382'), Support: 2
# Pattern: ('15819085', '487851005'), Support: 2
# Pattern: ('13462502', '487851005'), Support: 2
# Pattern: ('14267393',), Support: 11
# Pattern: ('14267393', '8866342'), Support: 2
# Pattern: ('83883736',), Support: 11
# Pattern: ('24008967',), Support: 11
# Pattern: ('24008967', '809760'), Support: 2
# Pattern: ('15903303',), Support: 11
# Pattern: ('15903303', '759251'), Support: 2
# Pattern: ('20543416', '250651231'), Support: 2
# Pattern: ('250651231', '742143'), Support: 2
# Pattern: ('104585489', '95428712'), Support: 2
# Pattern: ('329600057', '95428712'), Support: 2
# Pattern: ('391891226',), Support: 11
# Pattern: ('16792453', '26025129'), Support: 2
# Pattern: ('26025129', '26155776'), Support: 2
# Pattern: ('17577445', '32881068'), Support: 2
# Pattern: ('32881068', '8033482'), Support: 2
# Pattern: ('9844372',), Support: 11
# Pattern: ('20587987', '9844372'), Support: 2
# Pattern: ('5496642',), Support: 11
# Pattern: ('275353050', '755068'), Support: 2
# Pattern: ('275353050', '309366491'), Support: 2
# Pattern: ('14209885', '16511126'), Support: 2
# Pattern: ('16511126', '16930986'), Support: 2
# Pattern: ('16583846',), Support: 11
# Pattern: ('14995801', '16583846'), Support: 2
# Pattern: ('5027041',), Support: 11
# Pattern: ('19658936',), Support: 11
# Pattern: ('19658936', '30313925'), Support: 2
# Pattern: ('14809096', '713263'), Support: 2
# Pattern: ('14809096', '5813712'), Support: 2
# Pattern: ('19094625',), Support: 12
# Pattern: ('17408993', '586'), Support: 2
# Pattern: ('17408993', '287713'), Support: 2
# Pattern: ('13462502', '16353769'), Support: 2
# Pattern: ('16119767', '16353769'), Support: 2
# Pattern: ('16353769', '6088382'), Support: 2
# Pattern: ('16353769', '8630302'), Support: 2
# Pattern: ('19042640', '8630562'), Support: 2
# Pattern: ('174958347', '19042640'), Support: 2
# Pattern: ('15819085', '19042640'), Support: 2
# Pattern: ('1566521', '19042640'), Support: 2
# Pattern: ('35357461',), Support: 12
# Pattern: ('326658079',), Support: 12
# Pattern: ('15583257', '6731422'), Support: 2
# Pattern: ('19208772', '6731422'), Support: 2
# Pattern: ('5634142', '6731422'), Support: 2
# Pattern: ('57378470', '6731422'), Support: 2
# Pattern: ('1678471', '6731422'), Support: 2
# Pattern: ('14231571', '16317798'), Support: 2
# Pattern: ('16317798', '761'), Support: 2
# Pattern: ('16317798', '22253'), Support: 2
# Pattern: ('18317233', '20554406'), Support: 2
# Pattern: ('14086492', '18317233'), Support: 2
# Pattern: ('18317233', '9411772'), Support: 2
# Pattern: ('15814666',), Support: 12
# Pattern: ('145753059', '15814666'), Support: 2
# Pattern: ('39782670', '85416304'), Support: 2
# Pattern: ('27463744', '39782670'), Support: 2
# Pattern: ('39782670', '50888802'), Support: 2
# Pattern: ('15527013', '39782670'), Support: 2
# Pattern: ('15527013', '197141866'), Support: 2
# Pattern: ('197141866', '5413762'), Support: 2
# Pattern: ('197141866', '85416304'), Support: 2
# Pattern: ('15527013', '18681592'), Support: 2
# Pattern: ('18681592', '57186667'), Support: 2
# Pattern: ('18681592', '50888802'), Support: 2
# Pattern: ('18681592', '509323'), Support: 2
# Pattern: ('13607', '18681592'), Support: 2
# Pattern: ('18681592', '199032495'), Support: 2
# Pattern: ('45919912',), Support: 12
# Pattern: ('20642310',), Support: 12
# Pattern: ('11018782', '112391041'), Support: 2
# Pattern: ('112391041', '759251'), Support: 2
# Pattern: ('21456186',), Support: 12
# Pattern: ('145171509', '6066602'), Support: 2
# Pattern: ('145171509', '235117387'), Support: 2
# Pattern: ('145171509', '15862848'), Support: 2
# Pattern: ('22027186',), Support: 12
# Pattern: ('34232690',), Support: 12
# Pattern: ('14612743', '20587987'), Support: 2
# Pattern: ('14183255', '14612743'), Support: 2
# Pattern: ('18887526',), Support: 12
# Pattern: ('18887526', '19394186'), Support: 2
# Pattern: ('95495939',), Support: 12
# Pattern: ('16265198', '17800797'), Support: 2
# Pattern: ('16265198', '16304817'), Support: 2
# Pattern: ('15258591', '6271152'), Support: 2
# Pattern: ('3558801', '6271152'), Support: 2
# Pattern: ('14124059', '6271152'), Support: 2
# Pattern: ('4044361', '6271152'), Support: 2
# Pattern: ('16186995',), Support: 12
# Pattern: ('5725652',), Support: 12
# Pattern: ('30495974', '5725652'), Support: 2
# Pattern: ('14111698', '26955321'), Support: 2
# Pattern: ('13910012', '26955321'), Support: 2
# Pattern: ('26955321', '27478849'), Support: 2
# Pattern: ('12007182', '728163'), Support: 2
# Pattern: ('12007182', '14172562'), Support: 2
# Pattern: ('12007182', '14178728'), Support: 2
# Pattern: ('12007182', '51123'), Support: 2
# Pattern: ('12007182', '19223'), Support: 2
# Pattern: ('62415556',), Support: 13
# Pattern: ('62415556', '67157376'), Support: 2
# Pattern: ('15302100', '883301'), Support: 2
# Pattern: ('15302100', '67157376'), Support: 2
# Pattern: ('10587552', '22588327'), Support: 2
# Pattern: ('17729005', '22588327'), Support: 2
# Pattern: ('22084427', '234270825'), Support: 2
# Pattern: ('234270825', '8067082'), Support: 2
# Pattern: ('17853760',), Support: 13
# Pattern: ('145753059', '17853760'), Support: 2
# Pattern: ('16107051', '17643774'), Support: 2
# Pattern: ('15527013', '17643774'), Support: 2
# Pattern: ('15456622', '17643774'), Support: 2
# Pattern: ('12600372', '15527013'), Support: 2
# Pattern: ('12600372', '19996594'), Support: 2
# Pattern: ('12600372', '9870342'), Support: 2
# Pattern: ('12600372', '14120253'), Support: 2
# Pattern: ('12600372', '44984134'), Support: 2
# Pattern: ('12600372', '57186667'), Support: 2
# Pattern: ('1501471',), Support: 13
# Pattern: ('1501471', '3839'), Support: 2
# Pattern: ('16107051', '5413762'), Support: 2
# Pattern: ('15780631', '5413762'), Support: 2
# Pattern: ('5413762', '85416304'), Support: 2
# Pattern: ('15527013', '5413762'), Support: 2
# Pattern: ('104585489', '329600057'), Support: 2
# Pattern: ('329600057', '8170292'), Support: 2
# Pattern: ('243630696', '296319355'), Support: 2
# Pattern: ('19874960', '296319355'), Support: 2
# Pattern: ('265398605', '296319355'), Support: 2
# Pattern: ('19281401', '742143'), Support: 2
# Pattern: ('108352527', '19281401'), Support: 2
# Pattern: ('235117387', '6066602'), Support: 2
# Pattern: ('235117387', '42092597'), Support: 2
# Pattern: ('15862848', '235117387'), Support: 2
# Pattern: ('41907222',), Support: 13
# Pattern: ('24454827',), Support: 13
# Pattern: ('14352556', '24454827'), Support: 2
# Pattern: ('12307282', '17093224'), Support: 2
# Pattern: ('14616067', '17093224'), Support: 2
# Pattern: ('17093224', '297174372'), Support: 2
# Pattern: ('17093224', '27111653'), Support: 2
# Pattern: ('14048987', '3375371'), Support: 2
# Pattern: ('3375371', '793219'), Support: 2
# Pattern: ('1018211',), Support: 13
# Pattern: ('1018211', '13405'), Support: 2
# Pattern: ('16439471',), Support: 13
# Pattern: ('114463083',), Support: 13
# Pattern: ('114463083', '9460662'), Support: 2
# Pattern: ('14450509',), Support: 14
# Pattern: ('14086492', '9411772'), Support: 2
# Pattern: ('20554406', '9411772'), Support: 2
# Pattern: ('14142965', '9411772'), Support: 2
# Pattern: ('27985216', '8708232'), Support: 2
# Pattern: ('27985216', '3191321'), Support: 2
# Pattern: ('7415132', '8866342'), Support: 2
# Pattern: ('15109716', '8866342'), Support: 2
# Pattern: ('17864230', '8866342'), Support: 2
# Pattern: ('1678471', '183836186'), Support: 2
# Pattern: ('183836186', '18414485'), Support: 2
# Pattern: ('14819149', '183836186'), Support: 2
# Pattern: ('16007011', '183836186'), Support: 2
# Pattern: ('183836186', '19223'), Support: 2
# Pattern: ('11178592', '79033767'), Support: 2
# Pattern: ('20904050', '79033767'), Support: 2
# Pattern: ('11340982', '15456622'), Support: 2
# Pattern: ('15456622', '15527013'), Support: 2
# Pattern: ('15780631', '199032495'), Support: 2
# Pattern: ('199032495', '27463744'), Support: 2
# Pattern: ('199032495', '50888802'), Support: 2
# Pattern: ('14120253', '199032495'), Support: 2
# Pattern: ('145753059',), Support: 14
# Pattern: ('16303106',), Support: 14
# Pattern: ('205257492', '742143'), Support: 2
# Pattern: ('205257492', '27617013'), Support: 2
# Pattern: ('132195390', '205257492'), Support: 2
# Pattern: ('108352527', '205257492'), Support: 2
# Pattern: ('209584092',), Support: 14
# Pattern: ('209584092', '399933'), Support: 2
# Pattern: ('164220772', '696163'), Support: 2
# Pattern: ('164220772', '20587987'), Support: 2
# Pattern: ('15862848',), Support: 14
# Pattern: ('15363619', '4044361'), Support: 2
# Pattern: ('15363619', '297174372'), Support: 2
# Pattern: ('15363619', '27478849'), Support: 2
# Pattern: ('15363619', '6376372'), Support: 2
# Pattern: ('4958131', '8168192'), Support: 2
# Pattern: ('15438005', '4958131'), Support: 2
# Pattern: ('4958131', '821449'), Support: 2
# Pattern: ('16993577', '4958131'), Support: 2
# Pattern: ('14352556', '15033883'), Support: 2
# Pattern: ('14874480', '15033883'), Support: 2
# Pattern: ('15033883', '20282100'), Support: 2
# Pattern: ('14058661', '5963912'), Support: 2
# Pattern: ('15258591', '5963912'), Support: 2
# Pattern: ('3558801', '5963912'), Support: 2
# Pattern: ('13170222', '16993577'), Support: 2
# Pattern: ('13170222', '15438005'), Support: 2
# Pattern: ('13170222', '821449'), Support: 2
# Pattern: ('13170222', '27478849'), Support: 2
# Pattern: ('18139167', '4044361'), Support: 2
# Pattern: ('16727022', '18139167'), Support: 2
# Pattern: ('1765921',), Support: 15
# Pattern: ('17459034',), Support: 15
# Pattern: ('17459034', '883301'), Support: 2
# Pattern: ('17384098', '19101100'), Support: 2
# Pattern: ('19101100', '6253882'), Support: 2
# Pattern: ('14819149', '19101100'), Support: 2
# Pattern: ('19101100', '9283582'), Support: 2
# Pattern: ('19101100', '9767472'), Support: 2
# Pattern: ('15384741', '19101100'), Support: 2
# Pattern: ('17729005', '19101100'), Support: 2
# Pattern: ('10266802',), Support: 15
# Pattern: ('10266802', '509323'), Support: 2
# Pattern: ('809760',), Support: 15
# Pattern: ('17870415', '17870501'), Support: 2
# Pattern: ('17870501', '9406452'), Support: 2
# Pattern: ('17870501', '19579040'), Support: 2
# Pattern: ('15527013', '17870501'), Support: 2
# Pattern: ('15780631', '216126534'), Support: 2
# Pattern: ('19579040', '216126534'), Support: 2
# Pattern: ('216126534', '9406452'), Support: 2
# Pattern: ('17870415', '216126534'), Support: 2
# Pattern: ('15527013', '216126534'), Support: 2
# Pattern: ('216126534', '85416304'), Support: 2
# Pattern: ('120236782', '15224941'), Support: 2
# Pattern: ('120236782', '71294756'), Support: 2
# Pattern: ('104585489',), Support: 15
# Pattern: ('104585489', '399933'), Support: 2
# Pattern: ('14154272', '15944663'), Support: 2
# Pattern: ('15944663', '742143'), Support: 2
# Pattern: ('15944663', '7589572'), Support: 2
# Pattern: ('15944663', '8170292'), Support: 2
# Pattern: ('14191254', '15944663'), Support: 2
# Pattern: ('157044469', '621523'), Support: 2
# Pattern: ('14157134', '621523'), Support: 2
# Pattern: ('235180806', '621523'), Support: 2
# Pattern: ('113434348', '436383288'), Support: 2
# Pattern: ('113434348', '696163'), Support: 2
# Pattern: ('20587987', '696163'), Support: 2
# Pattern: ('18840531', '20587987'), Support: 2
# Pattern: ('80656590',), Support: 15
# Pattern: ('15918130', '51578914'), Support: 2
# Pattern: ('37450513', '51578914'), Support: 2
# Pattern: ('51578914', '712783'), Support: 2
# Pattern: ('51578914', '7668362'), Support: 2
# Pattern: ('14780571', '51578914'), Support: 2
# Pattern: ('7668362', '97399797'), Support: 2
# Pattern: ('15918130', '97399797'), Support: 2
# Pattern: ('712783', '97399797'), Support: 2
# Pattern: ('1375251', '14111698'), Support: 2
# Pattern: ('1375251', '16993577'), Support: 2
# Pattern: ('1375251', '27478849'), Support: 2
# Pattern: ('20282100', '5796972'), Support: 2
# Pattern: ('17220817', '20282100'), Support: 2
# Pattern: ('14995801', '655613'), Support: 2
# Pattern: ('14995801', '16993577'), Support: 2
# Pattern: ('14995801', '627363'), Support: 2
# Pattern: ('10751252', '14995801'), Support: 2
# Pattern: ('14995801', '15468786'), Support: 2
# Pattern: ('14995801', '7434252'), Support: 2
# Pattern: ('16120265', '309206712'), Support: 2
# Pattern: ('174853', '309206712'), Support: 2
# Pattern: ('17220817', '20005307'), Support: 2
# Pattern: ('20005307', '20793816'), Support: 2
# Pattern: ('20005307', '627363'), Support: 2
# Pattern: ('20005307', '697163'), Support: 2
# Pattern: ('13405', '5497452'), Support: 2
# Pattern: ('13405', '3839'), Support: 2
# Pattern: ('13405', '229523'), Support: 2
# Pattern: ('9184682',), Support: 15
# Pattern: ('5362182',), Support: 15
# Pattern: ('12101862', '16573941'), Support: 2
# Pattern: ('16573941', '5796972'), Support: 2
# Pattern: ('18498878', '57378470'), Support: 2
# Pattern: ('1678471', '18498878'), Support: 2
# Pattern: ('761', '765548'), Support: 2
# Pattern: ('6001592', '765548'), Support: 2
# Pattern: ('29294520', '765548'), Support: 2
# Pattern: ('47', '765548'), Support: 2
# Pattern: ('1371101', '14710479'), Support: 2
# Pattern: ('10476462', '1371101'), Support: 2
# Pattern: ('1371101', '17937655'), Support: 2
# Pattern: ('1371101', '15540222'), Support: 2
# Pattern: ('1371101', '1566521'), Support: 2
# Pattern: ('19966557',), Support: 16
# Pattern: ('13019862', '1678471'), Support: 2
# Pattern: ('13019862', '20904050'), Support: 2
# Pattern: ('13019862', '14305022'), Support: 2
# Pattern: ('13019862', '662423'), Support: 2
# Pattern: ('30331404',), Support: 16
# Pattern: ('16004268',), Support: 16
# Pattern: ('14367669', '16007011'), Support: 2
# Pattern: ('16007011', '1678471'), Support: 2
# Pattern: ('16007011', '21965123'), Support: 2
# Pattern: ('14183255', '344059195'), Support: 2
# Pattern: ('23487429', '344059195'), Support: 2
# Pattern: ('15078306', '15285444'), Support: 2
# Pattern: ('15285444', '16792453'), Support: 2
# Pattern: ('15285444', '16994322'), Support: 2
# Pattern: ('15285444', '15387870'), Support: 2
# Pattern: ('6066602',), Support: 16
# Pattern: ('127024694', '696163'), Support: 2
# Pattern: ('127024694', '21358559'), Support: 2
# Pattern: ('127024694', '18794066'), Support: 2
# Pattern: ('127024694', '436383288'), Support: 2
# Pattern: ('127024694', '14183255'), Support: 2
# Pattern: ('15918130', '17725506'), Support: 2
# Pattern: ('17725506', '271027935'), Support: 2
# Pattern: ('13753352', '655613'), Support: 2
# Pattern: ('13753352', '3594701'), Support: 2
# Pattern: ('13753352', '627363'), Support: 2
# Pattern: ('13753352', '14111698'), Support: 2
# Pattern: ('13753352', '9535182'), Support: 2
# Pattern: ('13753352', '9363302'), Support: 2
# Pattern: ('13753352', '14278964'), Support: 2
# Pattern: ('621713', '7434252'), Support: 2
# Pattern: ('10751252', '7434252'), Support: 2
# Pattern: ('563200400',), Support: 17
# Pattern: ('14087951', '668423'), Support: 2
# Pattern: ('15540222', '668423'), Support: 2
# Pattern: ('668423', '713263'), Support: 2
# Pattern: ('15775613', '6088382'), Support: 2
# Pattern: ('15775613', '6331462'), Support: 2
# Pattern: ('15775613', '883301'), Support: 2
# Pattern: ('15775613', '5854882'), Support: 2
# Pattern: ('14367669', '15775613'), Support: 2
# Pattern: ('15775613', '8630562'), Support: 2
# Pattern: ('15384741', '15801446'), Support: 2
# Pattern: ('10013512', '15801446'), Support: 2
# Pattern: ('15801446', '17729005'), Support: 2
# Pattern: ('15801446', '29294520'), Support: 2
# Pattern: ('15801446', '9283582'), Support: 2
# Pattern: ('14710479', '15801446'), Support: 2
# Pattern: ('15801446', '17384098'), Support: 2
# Pattern: ('1678471', '18414485'), Support: 2
# Pattern: ('18414485', '5994452'), Support: 2
# Pattern: ('15583257', '18414485'), Support: 2
# Pattern: ('18414485', '5634142'), Support: 2
# Pattern: ('20904050', '68824195'), Support: 2
# Pattern: ('1186', '68824195'), Support: 2
# Pattern: ('12741', '68824195'), Support: 2
# Pattern: ('11340982', '3839'), Support: 2
# Pattern: ('11340982', '16107051'), Support: 2
# Pattern: ('11340982', '755603'), Support: 2
# Pattern: ('104851609', '71294756'), Support: 2
# Pattern: ('104851609', '34310801'), Support: 2
# Pattern: ('11018782', '45536687'), Support: 2
# Pattern: ('45536687', '83590349'), Support: 2
# Pattern: ('132195390', '146449017'), Support: 2
# Pattern: ('146449017', '69860260'), Support: 2
# Pattern: ('34929990',), Support: 17
# Pattern: ('25491442', '34260638'), Support: 2
# Pattern: ('21358559', '34260638'), Support: 2
# Pattern: ('15387870', '34260638'), Support: 2
# Pattern: ('18396537', '23487429'), Support: 2
# Pattern: ('17872874', '23487429'), Support: 2
# Pattern: ('16792453', '23487429'), Support: 2
# Pattern: ('30957246', '34542541'), Support: 2
# Pattern: ('14968695', '34542541'), Support: 2
# Pattern: ('24585498', '34542541'), Support: 2
# Pattern: ('15078306', '34542541'), Support: 2
# Pattern: ('16792453', '34542541'), Support: 2
# Pattern: ('34542541', '42092597'), Support: 2
# Pattern: ('158314925',), Support: 17
# Pattern: ('36803580',), Support: 17
# Pattern: ('20586677', '24166202'), Support: 2
# Pattern: ('18731347', '20586677'), Support: 2
# Pattern: ('20586677', '63485337'), Support: 2
# Pattern: ('20586677', '8032822'), Support: 2
# Pattern: ('20586677', '211105430'), Support: 2
# Pattern: ('177564924', '20586677'), Support: 2
# Pattern: ('211105430', '282348945'), Support: 2
# Pattern: ('18731347', '282348945'), Support: 2
# Pattern: ('177564924', '282348945'), Support: 2
# Pattern: ('24166202', '282348945'), Support: 2
# Pattern: ('282348945', '63485337'), Support: 2
# Pattern: ('139750288', '16624991'), Support: 2
# Pattern: ('16624991', '3558801'), Support: 2
# Pattern: ('16624991', '17800797'), Support: 2
# Pattern: ('16624991', '6339822'), Support: 2
# Pattern: ('5746402',), Support: 17
# Pattern: ('16120265', '5746402'), Support: 2
# Pattern: ('31354534', '627363'), Support: 2
# Pattern: ('31354534', '697163'), Support: 2
# Pattern: ('17800797', '31354534'), Support: 2
# Pattern: ('12199652', '59353626'), Support: 2
# Pattern: ('14964767', '59353626'), Support: 2
# Pattern: ('14371227', '229523'), Support: 2
# Pattern: ('14344319', '14371227'), Support: 2
# Pattern: ('14371227', '15477919'), Support: 2
# Pattern: ('14371227', '27478849'), Support: 2
# Pattern: ('14066988', '14371227'), Support: 2
# Pattern: ('2038', '7924912'), Support: 2
# Pattern: ('16008396', '7924912'), Support: 2
# Pattern: ('4044361', '7924912'), Support: 2
# Pattern: ('3361871', '7924912'), Support: 2
# Pattern: ('3558801', '7924912'), Support: 2
# Pattern: ('14616067', '7924912'), Support: 2
# Pattern: ('14058661', '14297283'), Support: 2
# Pattern: ('14297283', '27478849'), Support: 2
# Pattern: ('13462502', '377821426'), Support: 2
# Pattern: ('377821426', '8630302'), Support: 2
# Pattern: ('174958347', '377821426'), Support: 2
# Pattern: ('15819085', '377821426'), Support: 2
# Pattern: ('377821426', '6088382'), Support: 2
# Pattern: ('5813712',), Support: 18
# Pattern: ('5813712', '713263'), Support: 2
# Pattern: ('528', '9863222'), Support: 2
# Pattern: ('47', '9863222'), Support: 2
# Pattern: ('6160742', '9863222'), Support: 2
# Pattern: ('6001592', '9863222'), Support: 2
# Pattern: ('6253882', '9767472'), Support: 2
# Pattern: ('21965123', '6253882'), Support: 2
# Pattern: ('17729005', '6253882'), Support: 2
# Pattern: ('14819149', '6253882'), Support: 2
# Pattern: ('6253882', '9283582'), Support: 2
# Pattern: ('17384098', '6253882'), Support: 2
# Pattern: ('15384741', '6253882'), Support: 2
# Pattern: ('17245224', '17937655'), Support: 2
# Pattern: ('17937655', '8630302'), Support: 2
# Pattern: ('15819085', '17937655'), Support: 2
# Pattern: ('17937655', '6088382'), Support: 2
# Pattern: ('17937655', '8630562'), Support: 2
# Pattern: ('17937655', '21965123'), Support: 2
# Pattern: ('17870415', '9406452'), Support: 2
# Pattern: ('17870415', '19579040'), Support: 2
# Pattern: ('15527013', '17870415'), Support: 2
# Pattern: ('17870415', '85416304'), Support: 2
# Pattern: ('21875245', '26213879'), Support: 2
# Pattern: ('21875245', '759251'), Support: 2
# Pattern: ('174377718', '21875245'), Support: 2
# Pattern: ('21875245', '26003862'), Support: 2
# Pattern: ('42866071', '76635157'), Support: 2
# Pattern: ('621533', '76635157'), Support: 2
# Pattern: ('17521796', '18794066'), Support: 2
# Pattern: ('15688048', '17521796'), Support: 2
# Pattern: ('17521796', '18396537'), Support: 2
# Pattern: ('234062645',), Support: 18
# Pattern: ('137365854', '16120265'), Support: 2
# Pattern: ('137365854', '14874480'), Support: 2
# Pattern: ('137365854', '24741685'), Support: 2
# Pattern: ('137365854', '74286565'), Support: 2
# Pattern: ('11336782', '14161531'), Support: 2
# Pattern: ('14161531', '627363'), Support: 2
# Pattern: ('12199652', '9535182'), Support: 2
# Pattern: ('14091119', '9535182'), Support: 2
# Pattern: ('14344319',), Support: 18
# Pattern: ('14344319', '15477919'), Support: 2
# Pattern: ('643443',), Support: 18
# Pattern: ('16008396', '27478849'), Support: 2
# Pattern: ('11336782', '16008396'), Support: 2
# Pattern: ('139750288', '16008396'), Support: 2
# Pattern: ('16008396', '8168192'), Support: 2
# Pattern: ('14178728', '20755177'), Support: 2
# Pattern: ('20755177', '8067082'), Support: 2
# Pattern: ('17864230', '20755177'), Support: 2
# Pattern: ('20755177', '22253'), Support: 2
# Pattern: ('20755177', '6735'), Support: 2
# Pattern: ('15459980', '20755177'), Support: 2
# Pattern: ('20755177', '51123'), Support: 2
# Pattern: ('20755177', '2735631'), Support: 2
# Pattern: ('10587552', '17729005'), Support: 2
# Pattern: ('10587552', '883301'), Support: 2
# Pattern: ('10587552', '8708232'), Support: 2
# Pattern: ('10587552', '9283582'), Support: 2
# Pattern: ('1678471', '17633994'), Support: 2
# Pattern: ('14710479', '17633994'), Support: 2
# Pattern: ('17633994', '5854882'), Support: 2
# Pattern: ('17633994', '883301'), Support: 2
# Pattern: ('17633994', '652193'), Support: 2
# Pattern: ('15583257', '17633994'), Support: 2
# Pattern: ('14367669', '17633994'), Support: 2
# Pattern: ('14471007', '5994452'), Support: 2
# Pattern: ('14471007', '40198602'), Support: 2
# Pattern: ('14471007', '1678471'), Support: 2
# Pattern: ('14471007', '8708232'), Support: 2
# Pattern: ('14471007', '713263'), Support: 2
# Pattern: ('14471007', '528'), Support: 2
# Pattern: ('14471007', '29294520'), Support: 2
# Pattern: ('6687652',), Support: 19
# Pattern: ('19208772', '57378470'), Support: 2
# Pattern: ('19208772', '5994452'), Support: 2
# Pattern: ('1678471', '19208772'), Support: 2
# Pattern: ('19208772', '5634142'), Support: 2
# Pattern: ('15583257', '19208772'), Support: 2
# Pattern: ('14892191',), Support: 19
# Pattern: ('14220606', '67157376'), Support: 2
# Pattern: ('14220606', '40198602'), Support: 2
# Pattern: ('14220606', '2727051'), Support: 2
# Pattern: ('14220606', '22253'), Support: 2
# Pattern: ('12741', '14220606'), Support: 2
# Pattern: ('174377718', '759251'), Support: 2
# Pattern: ('110458336', '174377718'), Support: 2
# Pattern: ('174377718', '9411482'), Support: 2
# Pattern: ('174377718', '26003862'), Support: 2
# Pattern: ('16184358', '174377718'), Support: 2
# Pattern: ('314553133', '8170292'), Support: 2
# Pattern: ('314553133', '42501345'), Support: 2
# Pattern: ('19580783', '26514893'), Support: 2
# Pattern: ('19580783', '21642976'), Support: 2
# Pattern: ('52000483',), Support: 19
# Pattern: ('47646874', '52000483'), Support: 2
# Pattern: ('18840531', '8033482'), Support: 2
# Pattern: ('18840531', '57572404'), Support: 2
# Pattern: ('14183255', '18840531'), Support: 2
# Pattern: ('17577445', '18840531'), Support: 2
# Pattern: ('15324044', '712783'), Support: 2
# Pattern: ('15324044', '755068'), Support: 2
# Pattern: ('14780571', '15324044'), Support: 2
# Pattern: ('211105430', '63485337'), Support: 2
# Pattern: ('211105430', '8032822'), Support: 2
# Pattern: ('18731347', '211105430'), Support: 2
# Pattern: ('211105430', '24166202'), Support: 2
# Pattern: ('177564924', '211105430'), Support: 2
# Pattern: ('14130860', '7668362'), Support: 2
# Pattern: ('14130860', '271027935'), Support: 2
# Pattern: ('14130860', '15918130'), Support: 2
# Pattern: ('14130860', '712783'), Support: 2
# Pattern: ('14616067', '6376372'), Support: 2
# Pattern: ('12307282', '14616067'), Support: 2
# Pattern: ('14616067', '297174372'), Support: 2
# Pattern: ('14079172', '14616067'), Support: 2
# Pattern: ('17800533', '5676102'), Support: 2
# Pattern: ('17800533', '1847381'), Support: 2
# Pattern: ('14278964', '17800533'), Support: 2
# Pattern: ('12199652', '17800533'), Support: 2
# Pattern: ('17800533', '627363'), Support: 2
# Pattern: ('17800533', '697163'), Support: 2
# Pattern: ('5637652', '7684302'), Support: 2
# Pattern: ('17800797', '7684302'), Support: 2
# Pattern: ('14086492',), Support: 20
# Pattern: ('12725022', '9616792'), Support: 2
# Pattern: ('663463', '9616792'), Support: 2
# Pattern: ('728163', '9616792'), Support: 2
# Pattern: ('14172562', '9616792'), Support: 2
# Pattern: ('15384741', '17384098'), Support: 2
# Pattern: ('17384098', '9283582'), Support: 2
# Pattern: ('17384098', '17729005'), Support: 2
# Pattern: ('14819149', '17384098'), Support: 2
# Pattern: ('13334762', '638323'), Support: 2
# Pattern: ('22253', '638323'), Support: 2
# Pattern: ('638323', '713263'), Support: 2
# Pattern: ('14087951', '638323'), Support: 2
# Pattern: ('11322372', '638323'), Support: 2
# Pattern: ('17245224', '6088382'), Support: 2
# Pattern: ('17245224', '8630302'), Support: 2
# Pattern: ('15819085', '17245224'), Support: 2
# Pattern: ('17245224', '8630562'), Support: 2
# Pattern: ('15109716',), Support: 20
# Pattern: ('20554406', '5634142'), Support: 2
# Pattern: ('1678471', '5634142'), Support: 2
# Pattern: ('15583257', '5634142'), Support: 2
# Pattern: ('5634142', '5994452'), Support: 2
# Pattern: ('13607', '9870342'), Support: 2
# Pattern: ('18030840', '9870342'), Support: 2
# Pattern: ('15527013', '9870342'), Support: 2
# Pattern: ('19996594', '9870342'), Support: 2
# Pattern: ('35702691', '9870342'), Support: 2
# Pattern: ('44984134', '9870342'), Support: 2
# Pattern: ('16107051', '9406452'), Support: 2
# Pattern: ('15527013', '16107051'), Support: 2
# Pattern: ('16107051', '50888802'), Support: 2
# Pattern: ('16107051', '7183482'), Support: 2
# Pattern: ('16107051', '85416304'), Support: 2
# Pattern: ('16107051', '27463744'), Support: 2
# Pattern: ('6598572', '91718540'), Support: 2
# Pattern: ('755603', '91718540'), Support: 2
# Pattern: ('15527013', '91718540'), Support: 2
# Pattern: ('50888802', '91718540'), Support: 2
# Pattern: ('618593',), Support: 20
# Pattern: ('41602160', '759251'), Support: 2
# Pattern: ('16184358', '41602160'), Support: 2
# Pattern: ('317313520', '41602160'), Support: 2
# Pattern: ('157044469', '235180806'), Support: 2
# Pattern: ('235180806', '8170292'), Support: 2
# Pattern: ('14157134', '235180806'), Support: 2
# Pattern: ('755068',), Support: 20
# Pattern: ('10228272',), Support: 20
# Pattern: ('972651',), Support: 20
# Pattern: ('309366491',), Support: 20
# Pattern: ('13055', '793219'), Support: 2
# Pattern: ('13055', '174853'), Support: 2
# Pattern: ('17220817', '5435752'), Support: 2
# Pattern: ('17220817', '20793816'), Support: 2
# Pattern: ('14058661', '27111653'), Support: 2
# Pattern: ('14058661', '14124059'), Support: 2
# Pattern: ('14058661', '27478849'), Support: 2
# Pattern: ('15468786', '821449'), Support: 2
# Pattern: ('15468786', '806170'), Support: 2
# Pattern: ('13910012', '15468786'), Support: 2
# Pattern: ('14111698', '15468786'), Support: 2
# Pattern: ('15468786', '8168192'), Support: 2
# Pattern: ('15468786', '27478849'), Support: 2
# Pattern: ('11628', '30495974'), Support: 2
# Pattern: ('11628', '2384071'), Support: 2
# Pattern: ('18193396', '655613'), Support: 2
# Pattern: ('14124059', '18193396'), Support: 2
# Pattern: ('139750288', '18193396'), Support: 2
# Pattern: ('14352556', '18193396'), Support: 2
# Pattern: ('18193396', '4044361'), Support: 2
# Pattern: ('11336782', '16338664'), Support: 2
# Pattern: ('16338664', '6376372'), Support: 2
# Pattern: ('12307282', '16338664'), Support: 2
# Pattern: ('16338664', '297174372'), Support: 2
# Pattern: ('16338664', '27478849'), Support: 2
# Pattern: ('139750288', '16959786'), Support: 2
# Pattern: ('16959786', '8168192'), Support: 2
# Pattern: ('174958347', '287713'), Support: 2
# Pattern: ('287713', '6160742'), Support: 2
# Pattern: ('287713', '3191321'), Support: 2
# Pattern: ('287713', '6331462'), Support: 2
# Pattern: ('287713', '586'), Support: 2
# Pattern: ('15384741', '9767472'), Support: 2
# Pattern: ('17729005', '9767472'), Support: 2
# Pattern: ('9283582', '9767472'), Support: 2
# Pattern: ('14819149', '9767472'), Support: 2
# Pattern: ('18030840', '68571415'), Support: 2
# Pattern: ('15527013', '68571415'), Support: 2
# Pattern: ('509323', '68571415'), Support: 2
# Pattern: ('44984134', '68571415'), Support: 2
# Pattern: ('27463744', '68571415'), Support: 2
# Pattern: ('19996594', '68571415'), Support: 2
# Pattern: ('35702691', '68571415'), Support: 2
# ...
# Pattern: ('51123', '528'), Support: 2
# Pattern: ('11178592', '51123'), Support: 2
# Pattern: ('51123', '713263'), Support: 2
# Pattern: ('14367669', '652193'), Support: 2
# Pattern: ('14367669', '8479062'), Support: 2
# Pattern: ('14305022', '14367669'), Support: 2
# Pattern: ('14367669', '5854882'), Support: 2
# Pattern: ('1186', '14367669'), Support: 2
# Pattern: ('14367669', '883301'), Support: 2
# Pattern: ('428333',), Support: 48
# Pattern: ('14157134', '8170292'), Support: 2
# Pattern: ('14157134', '41351472'), Support: 2
# Pattern: ('13434092', '14964767'), Support: 2
# Pattern: ('13434092', '16120265'), Support: 2
# Pattern: ('13434092', '5676102'), Support: 2
# Pattern: ('11375732', '13434092'), Support: 2
# Pattern: ('12199652', '13434092'), Support: 2
# Pattern: ('13434092', '13535762'), Support: 2
# Pattern: ('13434092', '16930986'), Support: 2
# Pattern: ('13434092', '15416485'), Support: 2
# Pattern: ('11336782', '3558801'), Support: 2
# Pattern: ('3558801', '4044361'), Support: 2
# Pattern: ('16304817', '3558801'), Support: 2
# Pattern: ('18852278', '3558801'), Support: 2
# Pattern: ('29294520', '528'), Support: 2
# Pattern: ('29294520', '883301'), Support: 2
# Pattern: ('29294520', '5854882'), Support: 2
# Pattern: ('29294520', '8479062'), Support: 2
# Pattern: ('29294520', '8630562'), Support: 2
# Pattern: ('1186', '713263'), Support: 2
# Pattern: ('22253', '713263'), Support: 2
# Pattern: ('12199652', '992031'), Support: 2
# Pattern: ('849131', '992031'), Support: 2
# Pattern: ('9460662', '992031'), Support: 2
# Pattern: ('14124059', '992031'), Support: 2
# Pattern: ('229523', '992031'), Support: 2
# Pattern: ('14305022', '8479062'), Support: 2
# Pattern: ('14305022', '652193'), Support: 2
# Pattern: ('11178592', '14305022'), Support: 2
# Pattern: ('14231571', '14305022'), Support: 2
# Pattern: ('14305022', '528'), Support: 2
# Pattern: ('57378470', '883301'), Support: 2
# Pattern: ('1678471', '57378470'), Support: 2
# Pattern: ('174958347', '57378470'), Support: 2
# Pattern: ('57378470', '8479062'), Support: 2
# Pattern: ('57378470', '5854882'), Support: 2
# Pattern: ('30043495', '71294756'), Support: 2
# Pattern: ('16184358', '30043495'), Support: 2
# Pattern: ('30043495', '9245812'), Support: 2
# Pattern: ('30043495', '759251'), Support: 2
# Pattern: ('16304817', '17800797'), Support: 2
# Pattern: ('16304817', '9460662'), Support: 2
# Pattern: ('14079172', '16304817'), Support: 2
# Pattern: ('16304817', '849131'), Support: 2
# Pattern: ('16304817', '18852278'), Support: 2
# Pattern: ('2735631', '652193'), Support: 2
# Pattern: ('2735631', '6735'), Support: 2
# Pattern: ('14231571', '2735631'), Support: 2
# Pattern: ('2735631', '528'), Support: 2
# Pattern: ('2735631', '586'), Support: 2
# Pattern: ('3839', '5637652'), Support: 2
# Pattern: ('12199652', '5637652'), Support: 2
# Pattern: ('11336782', '5637652'), Support: 2
# Pattern: ('2384071', '5637652'), Support: 2
# Pattern: ('16724361', '35629711'), Support: 2
# Pattern: ('11018782', '35629711'), Support: 2
# Pattern: ('22539758', '35629711'), Support: 2
# Pattern: ('16184358', '35629711'), Support: 2
# Pattern: ('35629711', '9411482'), Support: 2
# Pattern: ('16139105', '35629711'), Support: 2
# Pattern: ('35629711', '759251'), Support: 2
# Pattern: ('15078306', '42092597'), Support: 2
# Pattern: ('16792453', '42092597'), Support: 2
# Pattern: ('17872874', '42092597'), Support: 2
# Pattern: ('14183255', '42092597'), Support: 2
# Pattern: ('18396537', '42092597'), Support: 2
# Pattern: ('15387870', '42092597'), Support: 2
# Pattern: ('14111698',), Support: 51
# Pattern: ('621713', '849131'), Support: 2
# Pattern: ('621713', '627363'), Support: 2
# Pattern: ('621713', '793219'), Support: 2
# Pattern: ('24741685', '621713'), Support: 2
# Pattern: ('12199652', '621713'), Support: 2
# Pattern: ('16120265', '621713'), Support: 2
# Pattern: ('14124059', '229523'), Support: 2
# Pattern: ('13535762', '14124059'), Support: 2
# Pattern: ('14124059', '655613'), Support: 2
# Pattern: ('14124059', '849131'), Support: 2
# Pattern: ('14124059', '627363'), Support: 2
# Pattern: ('14124059', '793219'), Support: 2
# Pattern: ('14124059', '4044361'), Support: 2
# Pattern: ('16139105', '759251'), Support: 2
# Pattern: ('16139105', '9567972'), Support: 2
# Pattern: ('16139105', '34310801'), Support: 2
# Pattern: ('16139105', '16724361'), Support: 2
# Pattern: ('16139105', '71294756'), Support: 2
# Pattern: ('16139105', '22539758'), Support: 2
# Pattern: ('16139105', '9411482'), Support: 2
# Pattern: ('16139105', '2097571'), Support: 2
# Pattern: ('14154272', '20543416'), Support: 2
# Pattern: ('20543416', '8170292'), Support: 2
# Pattern: ('108352527', '20543416'), Support: 2
# Pattern: ('20543416', '41351472'), Support: 2
# Pattern: ('20543416', '74265849'), Support: 2
# Pattern: ('20543416', '21910500'), Support: 2
# Pattern: ('5854882', '8630562'), Support: 2
# Pattern: ('8630562', '883301'), Support: 2
# Pattern: ('16724361', '759251'), Support: 2
# Pattern: ('16724361', '22539758'), Support: 2
# Pattern: ('16724361', '22958682'), Support: 2
# Pattern: ('11018782', '16724361'), Support: 2
# Pattern: ('16724361', '71294756'), Support: 2
# Pattern: ('16724361', '34310801'), Support: 2
# Pattern: ('16724361', '9245812'), Support: 2
# Pattern: ('16724361', '9567972'), Support: 2
# Pattern: ('16184358', '16724361'), Support: 2
# Pattern: ('16724361', '9411482'), Support: 2
# Pattern: ('16724361', '2097571'), Support: 2
# Pattern: ('15078306', '18396537'), Support: 2
# Pattern: ('17872874', '18396537'), Support: 2
# Pattern: ('16792453', '18396537'), Support: 2
# Pattern: ('15387870', '18396537'), Support: 2
# Pattern: ('14183255', '15387870'), Support: 2
# Pattern: ('14183255', '17872874'), Support: 2
# Pattern: ('17800797', '18852278'), Support: 2
# Pattern: ('18852278', '4044361'), Support: 2
# Pattern: ('14079172', '18852278'), Support: 2
# Pattern: ('130584631', '18852278'), Support: 2
# Pattern: ('11375732', '849131'), Support: 2
# Pattern: ('11375732', '24741685'), Support: 2
# Pattern: ('11375732', '15416485'), Support: 2
# Pattern: ('11375732', '13535762'), Support: 2
# Pattern: ('11375732', '5676102'), Support: 2
# Pattern: ('11336782', '11375732'), Support: 2
# Pattern: ('11375732', '9460662'), Support: 2
# Pattern: ('11375732', '12199652'), Support: 2
# Pattern: ('11375732', '16120265'), Support: 2
# Pattern: ('14874480', '16120265'), Support: 2
# Pattern: ('14874480', '50393960'), Support: 2
# Pattern: ('14874480', '24741685'), Support: 2
# Pattern: ('14874480', '849131'), Support: 2
# Pattern: ('13535762', '14874480'), Support: 2
# Pattern: ('24741685', '74286565'), Support: 2
# Pattern: ('17800797', '74286565'), Support: 2
# Pattern: ('74286565', '849131'), Support: 2
# Pattern: ('229523', '74286565'), Support: 2
# Pattern: ('14964767', '74286565'), Support: 2
# Pattern: ('74286565', '9460662'), Support: 2
# Pattern: ('12199652', '74286565'), Support: 2
# Pattern: ('13535762', '74286565'), Support: 2
# Pattern: ('174958347', '8479062'), Support: 2
# Pattern: ('174958347', '586'), Support: 2
# Pattern: ('174958347', '6735'), Support: 2
# Pattern: ('1678471', '174958347'), Support: 2
# Pattern: ('22958682', '759251'), Support: 2
# Pattern: ('16184358', '22958682'), Support: 2
# Pattern: ('22958682', '236488883'), Support: 2
# Pattern: ('22958682', '9567972'), Support: 2
# Pattern: ('22958682', '9411482'), Support: 2
# Pattern: ('22958682', '9245812'), Support: 2
# Pattern: ('22539758', '759251'), Support: 2
# Pattern: ('22539758', '236488883'), Support: 2
# Pattern: ('22539758', '34310801'), Support: 2
# Pattern: ('16184358', '22539758'), Support: 2
# Pattern: ('528', '8479062'), Support: 2
# Pattern: ('652193', '8479062'), Support: 2
# Pattern: ('5854882', '8479062'), Support: 2
# Pattern: ('15078306', '16792453'), Support: 2
# Pattern: ('15078306', '15387870'), Support: 2
# Pattern: ('16120265', '16930986'), Support: 2
# Pattern: ('12199652', '16930986'), Support: 2
# Pattern: ('14964767', '16930986'), Support: 2
# Pattern: ('13535762', '16930986'), Support: 2
# Pattern: ('14079172', '16120265'), Support: 2
# Pattern: ('14079172', '627363'), Support: 2
# Pattern: ('14079172', '17800797'), Support: 2
# Pattern: ('14079172', '849131'), Support: 2
# Pattern: ('14079172', '9460662'), Support: 2
# Pattern: ('21910500', '41351472'), Support: 2
# Pattern: ('21910500', '74265849'), Support: 2
# Pattern: ('21910500', '8170292'), Support: 2
# Pattern: ('21910500', '243630696'), Support: 2
# Pattern: ('130584631', '17800797'), Support: 2
# Pattern: ('12199652', '130584631'), Support: 2
# Pattern: ('130584631', '15416485'), Support: 2
# Pattern: ('130584631', '9460662'), Support: 2
# Pattern: ('14964767', '24741685'), Support: 2
# Pattern: ('14964767', '15416485'), Support: 2
# Pattern: ('11178592', '14231571'), Support: 2
# Pattern: ('14231571', '528'), Support: 2
# Pattern: ('14231571', '652193'), Support: 2
# Pattern: ('108352527', '49492585'), Support: 2
# Pattern: ('108352527', '742143'), Support: 2
# Pattern: ('108352527', '74265849'), Support: 2
# Pattern: ('41351472', '49492585'), Support: 2
# Pattern: ('41351472', '74265849'), Support: 2
# Pattern: ('41351472', '8170292'), Support: 2
# Pattern: ('14154272', '41351472'), Support: 2
# Pattern: ('41351472', '742143'), Support: 2
# Pattern: ('243630696', '41351472'), Support: 2
# Pattern: ('180505807', '586'), Support: 2
# Pattern: ('1186', '180505807'), Support: 2
# Pattern: ('380', '883301'), Support: 2
# Pattern: ('380', '6735'), Support: 2
# Pattern: ('380', '652193'), Support: 2
# Pattern: ('380', '586'), Support: 2
# Pattern: ('528', '6735'), Support: 2
# Pattern: ('11178592', '6735'), Support: 2
# Pattern: ('652193', '6735'), Support: 2
# Pattern: ('655613',), Support: 61
# Pattern: ('1678471', '883301'), Support: 2
# Pattern: ('1186', '1678471'), Support: 2
# Pattern: ('1186', '5854882'), Support: 2
# Pattern: ('5854882', '883301'), Support: 2
# Pattern: ('22253', '5854882'), Support: 2
# Pattern: ('5854882', '652193'), Support: 2
# Pattern: ('229523', '3839'), Support: 2
# Pattern: ('13535762', '3839'), Support: 2
# Pattern: ('11336782', '3839'), Support: 2
# Pattern: ('14154272', '192318065'), Support: 2
# Pattern: ('14154272', '8170292'), Support: 2
# Pattern: ('16792453', '17872874'), Support: 2
# Pattern: ('15387870', '17872874'), Support: 2
# Pattern: ('17872874', '24585498'), Support: 2
# Pattern: ('1186', '883301'), Support: 2
# Pattern: ('652193', '883301'), Support: 2
# Pattern: ('192318065', '49492585'), Support: 2
# Pattern: ('49492585', '8170292'), Support: 2
# Pattern: ('49492585', '742143'), Support: 2
# Pattern: ('49492585', '74265849'), Support: 2
# Pattern: ('243630696', '49492585'), Support: 2
# Pattern: ('15387870', '24585498'), Support: 2
# Pattern: ('16792453', '24585498'), Support: 2
# Pattern: ('1186', '22253'), Support: 2
# Pattern: ('11178592', '22253'), Support: 2
# Pattern: ('236488883', '34310801'), Support: 2
# Pattern: ('236488883', '9245812'), Support: 2
# Pattern: ('236488883', '9411482'), Support: 2
# Pattern: ('236488883', '759251'), Support: 2
# Pattern: ('236488883', '9567972'), Support: 2
# Pattern: ('11018782', '71294756'), Support: 2
# Pattern: ('11018782', '9567972'), Support: 2
# Pattern: ('11018782', '2097571'), Support: 2
# Pattern: ('11018782', '759251'), Support: 2
# Pattern: ('11018782', '9411482'), Support: 2
# Pattern: ('11018782', '9245812'), Support: 2
# Pattern: ('11018782', '16184358'), Support: 2
# Pattern: ('17800797', '9460662'), Support: 2
# Pattern: ('17800797', '4044361'), Support: 2
# Pattern: ('12199652', '17800797'), Support: 2
# Pattern: ('17800797', '24741685'), Support: 2
# Pattern: ('192318065',), Support: 66
# Pattern: ('11178592', '586'), Support: 2
# Pattern: ('11178592', '1186'), Support: 2
# Pattern: ('11178592', '528'), Support: 2
# Pattern: ('16184358', '2097571'), Support: 2
# Pattern: ('2097571', '9567972'), Support: 2
# Pattern: ('2097571', '759251'), Support: 2
# Pattern: ('2097571', '71294756'), Support: 2
# Pattern: ('2097571', '9411482'), Support: 2
# Pattern: ('243630696', '8170292'), Support: 2
# Pattern: ('243630696', '74265849'), Support: 2
# Pattern: ('243630696', '742143'), Support: 2
# Pattern: ('229523', '27478849'), Support: 2
# Pattern: ('12199652', '27478849'), Support: 2
# Pattern: ('11336782', '27478849'), Support: 2
# Pattern: ('13535762', '27478849'), Support: 2
# Pattern: ('27478849', '849131'), Support: 2
# Pattern: ('16120265', '27478849'), Support: 2
# Pattern: ('27478849', '627363'), Support: 2
# Pattern: ('13535762', '793219'), Support: 2
# Pattern: ('229523', '793219'), Support: 2
# Pattern: ('793219', '849131'), Support: 2
# Pattern: ('793219', '9460662'), Support: 2
# Pattern: ('12199652', '793219'), Support: 2
# Pattern: ('5676102', '793219'), Support: 2
# Pattern: ('15416485', '793219'), Support: 2
# Pattern: ('1186', '652193'), Support: 2
# Pattern: ('586', '652193'), Support: 2
# Pattern: ('528', '652193'), Support: 2
# Pattern: ('528',), Support: 70
# Pattern: ('2384071',), Support: 70
# Pattern: ('2384071', '586'), Support: 2
# Pattern: ('16792453',), Support: 71
# Pattern: ('15387870', '16792453'), Support: 2
# Pattern: ('34310801', '759251'), Support: 2
# Pattern: ('34310801', '71294756'), Support: 2
# Pattern: ('34310801', '9245812'), Support: 2
# Pattern: ('34310801', '9411482'), Support: 2
# Pattern: ('15416485', '16120265'), Support: 2
# Pattern: ('12199652', '15416485'), Support: 2
# Pattern: ('15416485', '229523'), Support: 2
# Pattern: ('15416485', '5676102'), Support: 2
# Pattern: ('11336782', '15416485'), Support: 2
# Pattern: ('15416485', '627363'), Support: 2
# Pattern: ('13535762', '9460662'), Support: 2
# Pattern: ('11336782', '13535762'), Support: 2
# Pattern: ('12199652', '13535762'), Support: 2
# Pattern: ('13535762', '849131'), Support: 2
# Pattern: ('13535762', '24741685'), Support: 2
# Pattern: ('13535762', '229523'), Support: 2
# Pattern: ('13535762', '16120265'), Support: 2
# Pattern: ('759251', '9567972'), Support: 2
# Pattern: ('9245812', '9567972'), Support: 2
# Pattern: ('71294756', '9567972'), Support: 2
# Pattern: ('16184358', '9567972'), Support: 2
# Pattern: ('4044361', '9460662'), Support: 2
# Pattern: ('11336782', '4044361'), Support: 2
# Pattern: ('4044361', '849131'), Support: 2
# Pattern: ('16120265', '24741685'), Support: 2
# Pattern: ('229523', '24741685'), Support: 2
# Pattern: ('12199652', '24741685'), Support: 2
# Pattern: ('24741685', '9460662'), Support: 2
# Pattern: ('24741685', '50393960'), Support: 2
# Pattern: ('24741685', '5676102'), Support: 2
# Pattern: ('9245812', '9411482'), Support: 2
# Pattern: ('16184358', '9411482'), Support: 2
# Pattern: ('759251', '9411482'), Support: 2
# Pattern: ('11336782', '16120265'), Support: 2
# Pattern: ('16120265', '229523'), Support: 2
# Pattern: ('12199652', '16120265'), Support: 2
# Pattern: ('16120265', '9460662'), Support: 2
# Pattern: ('16120265', '627363'), Support: 2
# Pattern: ('16120265', '849131'), Support: 2
# Pattern: ('16120265', '50393960'), Support: 2
# Pattern: ('759251', '9245812'), Support: 2
# Pattern: ('16184358', '9245812'), Support: 2
# Pattern: ('71294756', '9245812'), Support: 2
# Pattern: ('15387870',), Support: 78
# Pattern: ('1186',), Support: 80
# Pattern: ('16184358', '759251'), Support: 2
# Pattern: ('16184358', '71294756'), Support: 2
# Pattern: ('8170292',), Support: 80
# Pattern: ('742143', '8170292'), Support: 2
# Pattern: ('71294756',), Support: 82
# Pattern: ('71294756', '759251'), Support: 2
# Pattern: ('742143',), Support: 82
# Pattern: ('742143', '74265849'), Support: 2
# Pattern: ('229523', '5676102'), Support: 2
# Pattern: ('11336782', '229523'), Support: 2
# Pattern: ('229523', '849131'), Support: 2
# Pattern: ('12199652', '229523'), Support: 2
# Pattern: ('74265849',), Support: 84
# Pattern: ('11336782', '9460662'), Support: 2
# Pattern: ('627363', '9460662'), Support: 2
# Pattern: ('12199652', '9460662'), Support: 2
# Pattern: ('5676102', '9460662'), Support: 2
# Pattern: ('849131', '9460662'), Support: 2
# Pattern: ('586',), Support: 88
# Pattern: ('12199652', '627363'), Support: 2
# Pattern: ('5676102', '627363'), Support: 2
# Pattern: ('11336782', '627363'), Support: 2
# Pattern: ('627363', '849131'), Support: 2
# Pattern: ('15527013',), Support: 95
# Pattern: ('12199652', '849131'), Support: 2
# Pattern: ('11336782', '849131'), Support: 2
# Pattern: ('12199652', '5676102'), Support: 2
# Pattern: ('11336782', '5676102'), Support: 2
# Pattern: ('50393960',), Support: 99
# Pattern: ('12199652',), Support: 102
# Pattern: ('11336782', '12199652'), Support: 2
# Pattern: ('759251',), Support: 110
# Pattern: ('11336782',), Support: 111

# %%
plt.figure(figsize=(12, 12))
nx.draw_networkx(G, with_labels=False, node_size=20, alpha=0.5, edge_color='r')
plt.title('Twitter Ego Network')
plt.show()

# %% [markdown]
# 步骤概述
#
# 1. 数据加载和合并:
#
# 目的: 加载文件夹中所有以特定节点ID前缀开头的.edges文件，并将它们合并成一个单一的数据集。
# 实现:
# os.listdir(folder_path)：列出指定文件夹下的所有文件。
# os.path.join(folder_path, f)：构建每个文件的完整路径。
# pd.read_csv(file, delim_whitespace=True, header=None, names=['source', 'target'])：读取每个文件，文件中的每一行包含两个节点，表示一个有向边。
#
# 2. 构建图和分析局部模式:
#
# 目的: 使用网络分析库NetworkX构建图形，分析节点的连接性，并识别图中的高度集中的子图。
# 实现:
# nx.from_pandas_edgelist(data, 'source', 'target', create_using=nx.DiGraph())：使用Pandas DataFrame中的数据创建一个有向图。
# nx.degree_centrality(G)：计算图中每个节点的中心性，中心性高意味着一个节点有更多的直接连接。
# G.subgraph(high_degree_nodes)：从图中提取出中心性高的节点，这些节点可能在社交网络中扮演重要角色，如意见领袖或关键传播者。
#
# 3. 可视化:
#
# 目的: 可视化分析结果，帮助直观理解数据和分析。
# 实现:
# plt.figure(figsize=(10, 10)) 和 nx.draw_networkx(...)：创建一个可视化图形，展示节点和它们之间的边，以便观察哪些节点在网络中占据中心位置。
# 目的和意义
# 通过上述代码，我们能够对一个特定的社交网络数据集（比如Twitter或Facebook的用户关系数据）进行局部模式分析。特别是，我们关注那些具有高度连接性的节点，这些节点在社交网络分析中往往具有重要意义：
#
# 意见领袖识别：在营销和信息传播研究中，识别能影响其他用户的关键节点（意见领袖）非常重要。
# 社区检测：通过识别连接紧密的节点群组，可以帮助我们理解社交网络中的社区结构。
# 信息流分析：了解信息如何在网络中流动，哪些节点在信息传播中起到桥梁作用。

# %% [markdown]
# ## 将该模式命名为领袖模式

# %%
from itertools import combinations

# %%
# 定义文件夹路径
folder_path = 'twitter'

# 读取一个圈子文件的内容
def read_circles(file_path):
    circles = []
    with open(file_path, 'r') as file:
        for line in file:
            circle = line.strip().split()[1:]  # 忽略圈子名称
            if circle:
                circles.append(circle)
    return circles

# 遍历文件夹读取所有圈子文件
def read_all_circles(folder_path):
    all_circles = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.circles'):
            full_path = os.path.join(folder_path, filename)
            circles = read_circles(full_path)
            all_circles.extend(circles)
    return all_circles

# 频繁模式挖掘
def frequent_patterns(circles, min_support=0.02):
    te = TransactionEncoder()
    te_ary = te.fit(circles).transform(circles)
    df = pd.DataFrame(te_ary, columns=te.columns_)
    frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
    return frequent_itemsets


# 使用网络图可视化频繁项集之间的关联
def visualize_frequent_patterns_with_network(frequent_itemsets, min_support=0.05):
    # 创建图对象
    G = nx.Graph()

    # 添加节点和边
    for index, row in frequent_itemsets.iterrows():
        # 为每个项集添加节点
        for item in row['itemsets']:
            G.add_node(item)

        # 为每对项集添加边，边的权重为支持度
        for (item1, item2) in combinations(row['itemsets'], 2):
            if G.has_edge(item1, item2):
                # 如果边已存在，增加权重
                G[item1][item2]['weight'] += row['support']
            else:
                # 添加新边
                G.add_edge(item1, item2, weight=row['support'])

    # 根据边的权重调整边的宽度
    edge_width = [G[u][v]['weight'] * 10 for u, v in G.edges()]

    # 绘制图形
    pos = nx.spring_layout(G, seed=42)  # 为了美观，使用spring布局
    nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=3000, edge_color='k', width=edge_width)
    plt.title('Network of Frequent Itemsets')
    plt.show()

# %%
# 处理所有文件
all_circles = read_all_circles(folder_path)
frequent_itemsets = frequent_patterns(all_circles)
print(frequent_itemsets)
# Out:
#      support                        itemsets
# 0   0.030750                     (195475105)
# 1   0.020664                     (197504076)
# 2   0.024600                     (216843160)
# 3   0.030996                      (22462180)
# 4   0.037638                      (34428380)
# 5   0.065437                      (40981798)
# 6   0.035424                      (43003845)
# 7   0.032472                      (88323281)
# 8   0.024600                      (97478285)
# 9   0.029028            (34428380, 22462180)
# 10  0.027552            (40981798, 22462180)
# 11  0.022386            (22462180, 43003845)
# 12  0.033702            (34428380, 40981798)
# 13  0.025092            (34428380, 43003845)
# 14  0.025584            (40981798, 43003845)
# 15  0.026076  (34428380, 22462180, 40981798)
# 16  0.021894  (34428380, 22462180, 43003845)
# 17  0.021402  (34428380, 40981798, 43003845)

# %%
# 可视化
visualize_frequent_patterns_with_network(frequent_itemsets)

# %% [markdown]
# 使用Apriori算法来识别那些频繁出现在一起的成员组合。这里，“频繁”是指组合出现的次数达到我们设定的支持度阈值。
#
# 首先，利用TransactionEncoder将圈子成员的列表转换成独热编码格式，这是Apriori算法处理的需要。然后，应用Apriori算法找出支持度不低于我们设定阈值的所有频繁项集。
#
# 输出的频繁项集和可视化结果揭示了哪些成员倾向于在多个圈子中共同出现。这可以帮助进一步分析这些成员之间可能存在的社交联系，或者这些成员在社交网络中的角色和影响力。
#
# 这个处理流程针对的是大规模的社交网络数据，通过上述步骤，我们可以有效地从大量复杂的社交圈子数据中提取出有意义的模式和关系。这种分析在社交网络研究、社区发现以及推荐系统等领域都有着广泛的应用。

# %% [markdown]
# ## 将该模式命名为社区模式
